# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_dir = "FER2013\\train" # Directory containing the training data
test_dir = "FER2013\\test"  # Directory containing the validation data

# %%
train_datagen = ImageDataGenerator(
    width_shift_range = 0.1,        # Randomly shift the width of images by up to 10%
    height_shift_range = 0.1,       # Randomly shift the height of images by up to 10%
    horizontal_flip = True,         # Flip images horizontally at random
    rescale = 1./255,               # Rescale pixel values to be between 0 and 1
    validation_split = 0.2          # Set aside 20% of the data for validation
)

validation_datagen = ImageDataGenerator(
    rescale = 1./255,               # Rescale pixel values to be between 0 and 1
    validation_split = 0.2          # Set aside 20% of the data for validation
)

# %%
train_generator = train_datagen.flow_from_directory(
    directory = train_dir,           # Directory containing the training data
    target_size = (48, 48),          # Resizes all images to 48x48 pixels
    batch_size = 64,                 # Number of images per batch
    color_mode = "grayscale",        # Converts the images to grayscale
    class_mode = "categorical",      # Classifies the images into 7 categories
    subset = "training"              # Uses the training subset of the data
)

validation_generator = validation_datagen.flow_from_directory(
    directory = test_dir,            # Directory containing the validation data
    target_size = (48, 48),          # Resizes all images to 48x48 pixels
    batch_size = 64,                 # Number of images per batch
    color_mode = "grayscale",        # Converts the images to grayscale
    class_mode = "categorical",      # Classifies the images into 7 categories
    subset = "validation"            # Uses the validation subset of the data
)
# Out:
# Found 22968 images belonging to 7 classes.
# Found 1432 images belonging to 7 classes.

# %%
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.models import Sequential
import tensorflow as tf 

# Define the model architecture
model = Sequential()

# Add a convolutional layer with 32 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48,48,1)))
# Add a batch normalization layer
model.add(BatchNormalization())
# Add a second convolutional layer with 64 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
# Add a second batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Add a third convolutional layer with 128 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Add a third batch normalization layer
model.add(BatchNormalization())
# Add a fourth convolutional layer with 128 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Add a fourth batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Add a fifth convolutional layer with 256 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
# Add a fifth batch normalization layer
model.add(BatchNormalization())
# Add a sixth convolutional layer with 256 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
# Add a sixth batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Flatten the output of the convolutional layers
model.add(Flatten())
# Add a dense layer with 256 neurons and relu activation function
model.add(Dense(256, activation='relu'))
# Add a seventh batch normalization layer
model.add(BatchNormalization())
# Add a dropout layer with 0.5 dropout rate
model.add(Dropout(0.5))
# Add a dense layer with 7 neurons (one for each class) and softmax activation function
model.add(Dense(7, activation='softmax'))

# Compile the model with categorical cross-entropy loss, adam optimizer, and accuracy metric
model.compile(loss="categorical_crossentropy", optimizer= tf.keras.optimizers.Adam(learning_rate=0.0001), metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the callback
checkpoint_callback = ModelCheckpoint(
    filepath='model_weights.h5',
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=False,
    mode='max',
    verbose=1
)

# Train the model with the callback
history = model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=50,
    validation_data=validation_generator,
    validation_steps=len(validation_generator),
    callbacks=[checkpoint_callback]
)
# Out:
# Epoch 1/50
# 359/359 [==============================] - ETA: 0s - loss: 2.7762 - accuracy: 0.1850
# Epoch 1: val_accuracy improved from -inf to 0.17947, saving model to model_weights.h5
# 359/359 [==============================] - 757s 2s/step - loss: 2.7762 - accuracy: 0.1850 - val_loss: 1.9552 - val_accuracy: 0.1795
# Epoch 2/50
# 359/359 [==============================] - ETA: 0s - loss: 2.3767 - accuracy: 0.2334
# Epoch 2: val_accuracy improved from 0.17947 to 0.31983, saving model to model_weights.h5
# 359/359 [==============================] - 223s 621ms/step - loss: 2.3767 - accuracy: 0.2334 - val_loss: 1.7432 - val_accuracy: 0.3198
# Epoch 3/50
# 359/359 [==============================] - ETA: 0s - loss: 2.1736 - accuracy: 0.2783
# Epoch 3: val_accuracy improved from 0.31983 to 0.36522, saving model to model_weights.h5
# 359/359 [==============================] - 219s 611ms/step - loss: 2.1736 - accuracy: 0.2783 - val_loss: 1.6739 - val_accuracy: 0.3652
# Epoch 4/50
# 359/359 [==============================] - ETA: 0s - loss: 2.0399 - accuracy: 0.3054
# Epoch 4: val_accuracy improved from 0.36522 to 0.38408, saving model to model_weights.h5
# 359/359 [==============================] - 214s 596ms/step - loss: 2.0399 - accuracy: 0.3054 - val_loss: 1.6332 - val_accuracy: 0.3841
# Epoch 5/50
# 359/359 [==============================] - ETA: 0s - loss: 1.9329 - accuracy: 0.3318
# Epoch 5: val_accuracy improved from 0.38408 to 0.42249, saving model to model_weights.h5
# 359/359 [==============================] - 217s 603ms/step - loss: 1.9329 - accuracy: 0.3318 - val_loss: 1.5689 - val_accuracy: 0.4225
# Epoch 6/50
# 359/359 [==============================] - ETA: 0s - loss: 1.8450 - accuracy: 0.3525
# Epoch 6: val_accuracy improved from 0.42249 to 0.45670, saving model to model_weights.h5
# 359/359 [==============================] - 213s 592ms/step - loss: 1.8450 - accuracy: 0.3525 - val_loss: 1.4754 - val_accuracy: 0.4567
# Epoch 7/50
# 359/359 [==============================] - ETA: 0s - loss: 1.7751 - accuracy: 0.3652
# Epoch 7: val_accuracy did not improve from 0.45670
# 359/359 [==============================] - 214s 596ms/step - loss: 1.7751 - accuracy: 0.3652 - val_loss: 1.4568 - val_accuracy: 0.4504
# Epoch 8/50
# 359/359 [==============================] - ETA: 0s - loss: 1.7189 - accuracy: 0.3789
# Epoch 8: val_accuracy improved from 0.45670 to 0.45810, saving model to model_weights.h5
# 359/359 [==============================] - 212s 591ms/step - loss: 1.7189 - accuracy: 0.3789 - val_loss: 1.4369 - val_accuracy: 0.4581
# Epoch 9/50
# 359/359 [==============================] - ETA: 0s - loss: 1.6563 - accuracy: 0.3996
# Epoch 9: val_accuracy improved from 0.45810 to 0.47765, saving model to model_weights.h5
# 359/359 [==============================] - 211s 588ms/step - loss: 1.6563 - accuracy: 0.3996 - val_loss: 1.3940 - val_accuracy: 0.4777
# Epoch 10/50
# 359/359 [==============================] - ETA: 0s - loss: 1.6003 - accuracy: 0.4168
# Epoch 10: val_accuracy improved from 0.47765 to 0.52584, saving model to model_weights.h5
# 359/359 [==============================] - 212s 590ms/step - loss: 1.6003 - accuracy: 0.4168 - val_loss: 1.3147 - val_accuracy: 0.5258
# Epoch 11/50
# 359/359 [==============================] - ETA: 0s - loss: 1.5490 - accuracy: 0.4313
# Epoch 11: val_accuracy did not improve from 0.52584
# 359/359 [==============================] - 212s 589ms/step - loss: 1.5490 - accuracy: 0.4313 - val_loss: 1.3320 - val_accuracy: 0.5028
# Epoch 12/50
# 359/359 [==============================] - ETA: 0s - loss: 1.5132 - accuracy: 0.4424
# Epoch 12: val_accuracy improved from 0.52584 to 0.52933, saving model to model_weights.h5
# 359/359 [==============================] - 212s 590ms/step - loss: 1.5132 - accuracy: 0.4424 - val_loss: 1.2818 - val_accuracy: 0.5293
# Epoch 13/50
# 359/359 [==============================] - ETA: 0s - loss: 1.4682 - accuracy: 0.4522
# Epoch 13: val_accuracy did not improve from 0.52933
# 359/359 [==============================] - 211s 588ms/step - loss: 1.4682 - accuracy: 0.4522 - val_loss: 1.2858 - val_accuracy: 0.5105
# Epoch 14/50
# 359/359 [==============================] - ETA: 0s - loss: 1.4303 - accuracy: 0.4673
# Epoch 14: val_accuracy improved from 0.52933 to 0.53492, saving model to model_weights.h5
# 359/359 [==============================] - 215s 598ms/step - loss: 1.4303 - accuracy: 0.4673 - val_loss: 1.2409 - val_accuracy: 0.5349
# Epoch 15/50
# 359/359 [==============================] - ETA: 0s - loss: 1.4000 - accuracy: 0.4779
# Epoch 15: val_accuracy improved from 0.53492 to 0.55168, saving model to model_weights.h5
# 359/359 [==============================] - 214s 597ms/step - loss: 1.4000 - accuracy: 0.4779 - val_loss: 1.1990 - val_accuracy: 0.5517
# Epoch 16/50
# 359/359 [==============================] - ETA: 0s - loss: 1.3680 - accuracy: 0.4858
# Epoch 16: val_accuracy did not improve from 0.55168
# 359/359 [==============================] - 212s 591ms/step - loss: 1.3680 - accuracy: 0.4858 - val_loss: 1.1967 - val_accuracy: 0.5517
# Epoch 17/50
# 359/359 [==============================] - ETA: 0s - loss: 1.3410 - accuracy: 0.4937
# Epoch 17: val_accuracy improved from 0.55168 to 0.56285, saving model to model_weights.h5
# 359/359 [==============================] - 214s 596ms/step - loss: 1.3410 - accuracy: 0.4937 - val_loss: 1.1573 - val_accuracy: 0.5628
# Epoch 18/50
# 359/359 [==============================] - ETA: 0s - loss: 1.3090 - accuracy: 0.5074
# Epoch 18: val_accuracy improved from 0.56285 to 0.57332, saving model to model_weights.h5
# 359/359 [==============================] - 214s 597ms/step - loss: 1.3090 - accuracy: 0.5074 - val_loss: 1.1409 - val_accuracy: 0.5733
# Epoch 19/50
# 359/359 [==============================] - ETA: 0s - loss: 1.2787 - accuracy: 0.5195
# Epoch 19: val_accuracy improved from 0.57332 to 0.58240, saving model to model_weights.h5
# 359/359 [==============================] - 214s 596ms/step - loss: 1.2787 - accuracy: 0.5195 - val_loss: 1.1447 - val_accuracy: 0.5824
# Epoch 20/50
# 359/359 [==============================] - ETA: 0s - loss: 1.2597 - accuracy: 0.5248
# Epoch 20: val_accuracy improved from 0.58240 to 0.58310, saving model to model_weights.h5
# 359/359 [==============================] - 215s 597ms/step - loss: 1.2597 - accuracy: 0.5248 - val_loss: 1.1127 - val_accuracy: 0.5831
# Epoch 21/50
# 359/359 [==============================] - ETA: 0s - loss: 1.2455 - accuracy: 0.5282
# Epoch 21: val_accuracy improved from 0.58310 to 0.58729, saving model to model_weights.h5
# 359/359 [==============================] - 219s 611ms/step - loss: 1.2455 - accuracy: 0.5282 - val_loss: 1.1260 - val_accuracy: 0.5873
# Epoch 22/50
# 359/359 [==============================] - ETA: 0s - loss: 1.2315 - accuracy: 0.5357
# Epoch 22: val_accuracy did not improve from 0.58729
# 359/359 [==============================] - 214s 596ms/step - loss: 1.2315 - accuracy: 0.5357 - val_loss: 1.1039 - val_accuracy: 0.5866
# Epoch 23/50
# 359/359 [==============================] - ETA: 0s - loss: 1.2118 - accuracy: 0.5407
# Epoch 23: val_accuracy improved from 0.58729 to 0.59288, saving model to model_weights.h5
# 359/359 [==============================] - 254s 708ms/step - loss: 1.2118 - accuracy: 0.5407 - val_loss: 1.1177 - val_accuracy: 0.5929
# Epoch 24/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1983 - accuracy: 0.5488
# Epoch 24: val_accuracy did not improve from 0.59288
# 359/359 [==============================] - 231s 644ms/step - loss: 1.1983 - accuracy: 0.5488 - val_loss: 1.1096 - val_accuracy: 0.5845
# Epoch 25/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1799 - accuracy: 0.5573
# Epoch 25: val_accuracy improved from 0.59288 to 0.59358, saving model to model_weights.h5
# 359/359 [==============================] - 220s 611ms/step - loss: 1.1799 - accuracy: 0.5573 - val_loss: 1.0945 - val_accuracy: 0.5936
# Epoch 26/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1664 - accuracy: 0.5613
# Epoch 26: val_accuracy improved from 0.59358 to 0.60056, saving model to model_weights.h5
# 359/359 [==============================] - 233s 650ms/step - loss: 1.1664 - accuracy: 0.5613 - val_loss: 1.0685 - val_accuracy: 0.6006
# Epoch 27/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1497 - accuracy: 0.5671
# Epoch 27: val_accuracy did not improve from 0.60056
# 359/359 [==============================] - 221s 614ms/step - loss: 1.1497 - accuracy: 0.5671 - val_loss: 1.0616 - val_accuracy: 0.6006
# Epoch 28/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1409 - accuracy: 0.5704
# Epoch 28: val_accuracy improved from 0.60056 to 0.61522, saving model to model_weights.h5
# 359/359 [==============================] - 224s 623ms/step - loss: 1.1409 - accuracy: 0.5704 - val_loss: 1.0313 - val_accuracy: 0.6152
# Epoch 29/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1288 - accuracy: 0.5752
# Epoch 29: val_accuracy did not improve from 0.61522
# 359/359 [==============================] - 223s 620ms/step - loss: 1.1288 - accuracy: 0.5752 - val_loss: 1.0533 - val_accuracy: 0.6068
# Epoch 30/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1255 - accuracy: 0.5801
# Epoch 30: val_accuracy did not improve from 0.61522
# 359/359 [==============================] - 222s 617ms/step - loss: 1.1255 - accuracy: 0.5801 - val_loss: 1.0583 - val_accuracy: 0.6041
# Epoch 31/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1143 - accuracy: 0.5818
# Epoch 31: val_accuracy improved from 0.61522 to 0.62430, saving model to model_weights.h5
# 359/359 [==============================] - 222s 619ms/step - loss: 1.1143 - accuracy: 0.5818 - val_loss: 1.0336 - val_accuracy: 0.6243
# Epoch 32/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1078 - accuracy: 0.5836
# Epoch 32: val_accuracy did not improve from 0.62430
# 359/359 [==============================] - 218s 606ms/step - loss: 1.1078 - accuracy: 0.5836 - val_loss: 1.0468 - val_accuracy: 0.6117
# Epoch 33/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0856 - accuracy: 0.5951
# Epoch 33: val_accuracy did not improve from 0.62430
# 359/359 [==============================] - 217s 604ms/step - loss: 1.0856 - accuracy: 0.5951 - val_loss: 1.0164 - val_accuracy: 0.6243
# Epoch 34/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0739 - accuracy: 0.5990
# Epoch 34: val_accuracy did not improve from 0.62430
# 359/359 [==============================] - 220s 610ms/step - loss: 1.0739 - accuracy: 0.5990 - val_loss: 1.0092 - val_accuracy: 0.6159
# Epoch 35/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0740 - accuracy: 0.5955
# Epoch 35: val_accuracy did not improve from 0.62430
# 359/359 [==============================] - 219s 610ms/step - loss: 1.0740 - accuracy: 0.5955 - val_loss: 1.0382 - val_accuracy: 0.6047
# Epoch 36/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0641 - accuracy: 0.6027
# Epoch 36: val_accuracy did not improve from 0.62430
# 359/359 [==============================] - 219s 607ms/step - loss: 1.0641 - accuracy: 0.6027 - val_loss: 1.0375 - val_accuracy: 0.6187
# Epoch 37/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0578 - accuracy: 0.6048
# Epoch 37: val_accuracy improved from 0.62430 to 0.63059, saving model to model_weights.h5
# 359/359 [==============================] - 222s 615ms/step - loss: 1.0578 - accuracy: 0.6048 - val_loss: 0.9899 - val_accuracy: 0.6306
# Epoch 38/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0472 - accuracy: 0.6074
# Epoch 38: val_accuracy improved from 0.63059 to 0.63128, saving model to model_weights.h5
# 359/359 [==============================] - 222s 619ms/step - loss: 1.0472 - accuracy: 0.6074 - val_loss: 0.9896 - val_accuracy: 0.6313
# Epoch 39/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0349 - accuracy: 0.6091
# Epoch 39: val_accuracy did not improve from 0.63128
# 359/359 [==============================] - 220s 613ms/step - loss: 1.0349 - accuracy: 0.6091 - val_loss: 1.0137 - val_accuracy: 0.6187
# Epoch 40/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0334 - accuracy: 0.6107
# Epoch 40: val_accuracy improved from 0.63128 to 0.64106, saving model to model_weights.h5
# 359/359 [==============================] - 220s 612ms/step - loss: 1.0334 - accuracy: 0.6107 - val_loss: 0.9864 - val_accuracy: 0.6411
# Epoch 41/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0330 - accuracy: 0.6142
# Epoch 41: val_accuracy did not improve from 0.64106
# 359/359 [==============================] - 229s 639ms/step - loss: 1.0330 - accuracy: 0.6142 - val_loss: 0.9845 - val_accuracy: 0.6299
# Epoch 42/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0160 - accuracy: 0.6176
# Epoch 42: val_accuracy did not improve from 0.64106
# 359/359 [==============================] - 233s 648ms/step - loss: 1.0160 - accuracy: 0.6176 - val_loss: 1.0145 - val_accuracy: 0.6369
# Epoch 43/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0038 - accuracy: 0.6244
# Epoch 43: val_accuracy did not improve from 0.64106
# 359/359 [==============================] - 208s 578ms/step - loss: 1.0038 - accuracy: 0.6244 - val_loss: 0.9702 - val_accuracy: 0.6411
# Epoch 44/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0041 - accuracy: 0.6254
# Epoch 44: val_accuracy did not improve from 0.64106
# 359/359 [==============================] - 208s 579ms/step - loss: 1.0041 - accuracy: 0.6254 - val_loss: 0.9773 - val_accuracy: 0.6362
# Epoch 45/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9960 - accuracy: 0.6269
# Epoch 45: val_accuracy improved from 0.64106 to 0.64385, saving model to model_weights.h5
# 359/359 [==============================] - 208s 580ms/step - loss: 0.9960 - accuracy: 0.6269 - val_loss: 0.9581 - val_accuracy: 0.6439
# Epoch 46/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9895 - accuracy: 0.6277
# Epoch 46: val_accuracy did not improve from 0.64385
# 359/359 [==============================] - 207s 577ms/step - loss: 0.9895 - accuracy: 0.6277 - val_loss: 1.0115 - val_accuracy: 0.6278
# Epoch 47/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9854 - accuracy: 0.6324
# Epoch 47: val_accuracy improved from 0.64385 to 0.64665, saving model to model_weights.h5
# 359/359 [==============================] - 209s 581ms/step - loss: 0.9854 - accuracy: 0.6324 - val_loss: 0.9608 - val_accuracy: 0.6466
# Epoch 48/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9804 - accuracy: 0.6351
# Epoch 48: val_accuracy did not improve from 0.64665
# 359/359 [==============================] - 209s 582ms/step - loss: 0.9804 - accuracy: 0.6351 - val_loss: 0.9397 - val_accuracy: 0.6446
# Epoch 49/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9705 - accuracy: 0.6338
# Epoch 49: val_accuracy improved from 0.64665 to 0.64735, saving model to model_weights.h5
# 359/359 [==============================] - 209s 581ms/step - loss: 0.9705 - accuracy: 0.6338 - val_loss: 0.9408 - val_accuracy: 0.6473
# Epoch 50/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9603 - accuracy: 0.6413
# Epoch 50: val_accuracy did not improve from 0.64735
# 359/359 [==============================] - 208s 580ms/step - loss: 0.9603 - accuracy: 0.6413 - val_loss: 0.9499 - val_accuracy: 0.6459

# %%
from tensorflow.keras.models import load_model

model = load_model("model_weights.h5")

# Compile the model with categorical cross-entropy loss, adam optimizer, and accuracy metric
model.compile(loss="categorical_crossentropy", optimizer= tf.keras.optimizers.Adam(learning_rate=0.0001), metrics=['accuracy'])

# Define the callback
checkpoint_callback = ModelCheckpoint(
    filepath='model_weights.h5',
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=False,
    mode='max',
    verbose=1
)

# Train the model with the callback
history = model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=50,
    validation_data=validation_generator,
    validation_steps=len(validation_generator),
    callbacks=[checkpoint_callback]
)
# Out:
# 359/359 [==============================] - ETA: 0s - loss: 0.9613 - accuracy: 0.6405
# Epoch 1: val_accuracy improved from -inf to 0.63478, saving model to model_weights.h5
# 359/359 [==============================] - 695s 2s/step - loss: 0.9613 - accuracy: 0.6405 - val_loss: 0.9727 - val_accuracy: 0.6348
